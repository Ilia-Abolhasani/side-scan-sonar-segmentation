# %%
import cv2
import PIL
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
PIL.Image.MAX_IMAGE_PIXELS = 933120000
# %matplotlib inline

# %%
# !wget http://data.jncc.gov.uk/data/05229b73-2215-46a0-81e3-2442f60b1bdb-ss-geotiff.zip

# %%
# !unzip /content/05229b73-2215-46a0-81e3-2442f60b1bdb-ss-geotiff.zip

# %%
im = Image.open('WBRF_20130318_SS_0D3_UTM30N_box1.TIF', 'r')

# %%
with open('WBRF_20130318_SS_0D3_UTM30N_box1.TIF.xml','r') as file:
    text = file.read()

# %%
fig = plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
plt.imshow(np.asarray(im))
